# %%
# %load_ext autoreload

# %%
# %autoreload
import functools

import blackjax
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np
import pears
from gaul import advi, hmc, quap
from gaul.utils import pbar
from jax.scipy import stats
from tqdm.auto import tqdm

# %%
t = jnp.array([0.0, 49.452, 95.393, 127.587, 190.408])
rv = jnp.array([38.77, 39.70, 37.45, 38.31, 38.31])
err = jnp.array([0.184, 0.261, 0.112, 0.155, 0.223])
plt.errorbar(t, rv, yerr=err, ls="none", marker="o")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
@jax.jit
def forward(params, data):
    omega = 2.0 * np.pi / params["P"]
    v = params["v0"] + params["K"] * jnp.cos(omega * data["t"] + params["phi"])
    return v

# %%
@jax.jit
def log_prob(params, data):
    l = 0.0

    v = forward(params, data)
    l += stats.norm.logpdf(data["v"], v, data["err"]).sum()

    l += stats.uniform.logpdf(
        jnp.log(params["P"]), jnp.log(data["Pmin"]), jnp.log(data["Pmax"])
    )
    l += stats.uniform.logpdf(params["phi"], 0.0, 2.0 * jnp.pi)
    l += stats.norm.logpdf(params["v0"], 0.0, data["sigma_v0"])
    l += stats.norm.logpdf(params["K"], data["mu_K"], data["sigma_K"])

    return l.sum()

# %%
params = dict(
    P=jnp.array([10.0]),
    v0=jnp.array([30.0]),
    K=jnp.array([7.0]),
    phi=jnp.array([0.0]),
)
data = dict(
    t=t,
    v=rv,
    err=err,
    Pmin=jnp.array([2.0]),
    Pmax=jnp.array([256.0]),
    sigma_v0=jnp.array([100.0]),
    mu_K=jnp.array([1.0]),
    sigma_K=jnp.array([30.0]),
)

# %%
log_prob_fn = jax.jit(functools.partial(log_prob, data=data))

# Build the kernel
step_size = 1e-2
inverse_mass_matrix = jnp.ones(4)
nuts = blackjax.nuts(log_prob_fn, step_size, inverse_mass_matrix)

# Initialize the state
state = nuts.init(params)

# %%
def inference_loop(rng_key, kernel, initial_state, n_warmup, n_sample):
    @jax.jit
    def step(state, rng_key):
        state, _ = kernel(rng_key, state)
        return state, state

    keys_warmup = jax.random.split(rng_key, n_warmup + 1)
    carry, _ = jax.lax.scan(step, initial_state, keys_warmup[:-1])
    state, _ = carry

    keys_sample = jax.random.split(keys_warmup[-1], n_sample)
    carry, states = jax.lax.scan(step, state, keys_sample)
    final_state, _ = carry

    return final_state, states

# %%
kernel = jax.jit(nuts.step)
key = jax.random.PRNGKey(0)
states = inference_loop(key, kernel, state, 10000, 1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [191], line 3
#       1 kernel = jax.jit(nuts.step)
#       2 key = jax.random.PRNGKey(0)
# ----> 3 states = inference_loop(key, kernel, state, 10000, 1000)
#
# Cell In [190], line 10, in inference_loop(rng_key, kernel, initial_state, n_warmup, n_sample)
#       8 keys_warmup = jax.random.split(rng_key, n_warmup + 1)
#       9 pb_warmup = pbar.progress_bar_scan(n_warmup, "Warming up")
# ---> 10 carry, _ = jax.lax.scan(pb_warmup(step), (initial_state, keys_warmup[:-1]), jnp.arange(n_warmup))
#      11 state, _ = carry
#      13 keys_sample = jax.random.split(keys_warmup[-1], n_sample)
#
#     [... skipping hidden 11 frame]
#
# File /scratch/gpfs/js5013/.conda/envs/main/lib/python3.10/site-packages/gaul/utils/pbar.py:81, in progress_bar_scan.<locals>._progress_bar_scan.<locals>.wrapper_progress_bar(carry, x)
#      79     iter_num = x
#      80 _update_progress_bar(iter_num)
# ---> 81 result = func(carry, x)
#      82 return close_tqdm(result, iter_num)
#
#     [... skipping hidden 7 frame]
#
# Cell In [190], line 5, in inference_loop.<locals>.step(carry, iter_num)
#       2 @jax.jit
#       3 def step(carry, iter_num):
#       4     state, rng_key = carry
# ----> 5     state, _ = kernel(rng_key, state)
#       6     return (state, rng_key), state
#
#     [... skipping hidden 7 frame]
#
# File /scratch/gpfs/js5013/.conda/envs/main/lib/python3.10/site-packages/blackjax/kernels.py:385, in nuts.__new__.<locals>.step_fn(rng_key, state)
#     384 def step_fn(rng_key: PRNGKey, state):
# --> 385     return step(
#     386         rng_key,
#     387         state,
#     388         logprob_fn,
#     389         step_size,
#     390         inverse_mass_matrix,
#     391         logprob_grad_fn=logprob_grad_fn,
#     392     )
#
# File /scratch/gpfs/js5013/.conda/envs/main/lib/python3.10/site-packages/blackjax/mcmc/nuts.py:134, in kernel.<locals>.one_step(rng_key, state, logprob_fn, step_size, inverse_mass_matrix, logprob_grad_fn)
#     123 symplectic_integrator = integrator(
#     124     potential_fn, kinetic_energy_fn, logprob_grad_fn
#     125 )
#     126 proposal_generator = iterative_nuts_proposal(
#     127     symplectic_integrator,
#     128     kinetic_energy_fn,
#    (...)
#     131     divergence_threshold,
#     132 )
# --> 134 key_momentum, key_integrator = jax.random.split(rng_key, 2)
#     136 position, potential_energy, potential_energy_grad = state
#     137 momentum = momentum_generator(key_momentum, position)
#
# ValueError: too many values to unpack (expected 2)

# %%
nuts.step(

# %%
samples = hmc.sample(
    log_prob,
    params,
    data=data,
    step_size=0.0005,
    n_warmup=4000,
)
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 4))
for i, k in enumerate(states.position.keys()):
    for c in range(1):
        ax[i].plot(states.position[k][:, 0], alpha=0.3)

# %%
samples = jax.tree_map(lambda x: x.ravel(), samples)

# %%
pears.pears(samples);

# %%
tnew = np.linspace(t.min(), t.max(), 500)
vnew = jax.vmap(forward, in_axes=({k: 0 for k in samples.keys()}, None))(
    dict(samples), dict(t=tnew)
)

# %%
plt.errorbar(t, rv, yerr=err, ls="none", marker="o")
for i in range(100):
    plt.plot(tnew, vnew[i], alpha=0.2, c="gray")
