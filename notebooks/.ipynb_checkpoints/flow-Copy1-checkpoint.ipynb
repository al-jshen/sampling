# %%
# %load_ext autoreload

# %%
# %autoreload

import abc
from functools import partial
from typing import Any, Callable, Mapping, Optional, Sequence

import chex
import distrax
import flax.linen as nn
import jax
import jax.numpy as jnp
import jax.scipy.special as special
import jax.scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
import optax
from jax import random
from tqdm.auto import tqdm

Array = jnp.ndarray
PRNGKey = Array
Batch = Mapping[str, np.ndarray]
OptState = Any

# %% [markdown]
# # elbo helpers

# %%
def diag_gaussian_sample(rng, mean, log_std):
    # Take a single sample from a diagonal multivariate Gaussian.
    return mean + jnp.exp(log_std) * random.normal(rng, mean.shape)


def diag_gaussian_logpdf(x, mean, log_std):
    # Evaluate a single point on a diagonal multivariate Gaussian.
    return jnp.sum(jax.vmap(stats.norm.logpdf)(x, mean, jnp.exp(log_std)))


def elbo(logprob, rng, mean, log_std):
    # Single-sample Monte Carlo estimate of the variational lower bound.
    sample = diag_gaussian_sample(rng, mean, log_std)
    return logprob(sample) - diag_gaussian_logpdf(sample, mean, log_std)


def batch_elbo(logprob, rng, params, num_samples):
    # Average over a batch of random samples.
    rngs = random.split(rng, num_samples)
    vectorized_elbo = jax.vmap(partial(elbo, logprob), in_axes=(0, None, None))
    return jnp.mean(vectorized_elbo(rngs, *params))

# %% [markdown]
# # normalizing flow

# %%
class MLP(nn.Module):
    """A multi-layer perceptron (MLP)."""

    latent_sizes: Sequence[int]
    activation: Optional[Callable[[chex.Array], chex.Array]]
    skip_connections: bool = True
    activate_final: bool = False

    @nn.compact
    def __call__(self, inputs):
        for index, dim in enumerate(self.latent_sizes):
            next_inputs = nn.Dense(dim)(inputs)

            if index != len(self.latent_sizes) - 1 or self.activate_final:
                if self.activation is not None:
                    next_inputs = self.activation(next_inputs)

            if self.skip_connections and next_inputs.shape == inputs.shape:
                next_inputs = next_inputs + inputs

            inputs = next_inputs
        return inputs

# %%
class FlowConditioner(nn.Module):
    """Conditioner for the masked coupling normalizing flow."""

    event_shape: Sequence[int]
    latent_sizes: Sequence[int]
    activation: Callable[[chex.Array], chex.Array]
    num_bijector_params: int

    @nn.compact
    def __call__(self, inputs):
        inputs = jnp.reshape(inputs, (inputs.shape[0], -1))
        # inputs = jnp.reshape(inputs, (-1, *event_shape))
        inputs = MLP(self.latent_sizes, self.activation, activate_final=True)(inputs)
        # zero initialization for linear layer so flow starts as identity
        inputs = nn.Dense(
            np.prod(self.event_shape) * self.num_bijector_params,
            kernel_init=nn.initializers.zeros,
            bias_init=nn.initializers.zeros,
        )(inputs)
        inputs = jnp.reshape(
            inputs,
            inputs.shape[:-1] + tuple(self.event_shape) + (self.num_bijector_params,),
        )
        return inputs

# %%
@nn.jit
class NormalizingFlow(nn.Module):
    """Implements a masked coupling normalizing flow."""

    event_shape: Sequence[int]
    bijector_fn: Callable[[optax.Params], distrax.Bijector]
    conditioners: Sequence[FlowConditioner]

    def setup(self):
        ndim = np.prod(self.event_shape)

        # Alternating binary mask.
        mask = jnp.arange(0, ndim) % 2
        mask = jnp.reshape(mask, self.event_shape)
        mask = mask.astype(bool)

        layers = []
        for conditioner in self.conditioners:
            layer = distrax.MaskedCoupling(
                mask=mask, bijector=self.bijector_fn, conditioner=conditioner
            )
            layers.append(layer)

            # Flip the mask after each layer.
            mask = jnp.logical_not(mask)

        # Chain layers to create the flow.
        self.flow = distrax.Chain(layers)
        self.base_dist = distrax.Independent(
            distrax.MultivariateNormalFullCovariance(
                loc=jnp.zeros(ndim),
                covariance_matrix=jnp.eye(ndim),
            )
        )
        self.trans_dist = distrax.Transformed(self.base_dist, self.flow)
        return self.flow, self.base_dist, self.trans_dist

    def __call__(self, inputs: Array):
        return self.forward(inputs)

    def forward(self, inputs: Array):
        return self.flow.forward(inputs)

    def inverse(self, inputs: Array):
        return self.flow.inverse(inputs)

    def sample_base(self, key: PRNGKey, n: int):
        return self.base_dist.sample(seed=key, sample_shape=n)

    def sample_transformed(self, key: PRNGKey, n: int):
        z = self.sample_base(key, n)
        return self.forward(z)

    def sample_and_log_prob_base(self, key: PRNGKey, n: int):
        return self.base_dist.sample_and_log_prob(seed=key, sample_shape=n)

    def sample_and_log_prob_transformed(self, key: PRNGKey, n: int):
        z = self.sample_transformed(key, n)
        return z, self.log_prob_transformed(z)

    def forward_and_log_det(self, inputs: Array):
        """Encodes inputs as latent vectors."""
        return self.flow.forward_and_log_det(inputs)

    def inverse_and_log_det(self, inputs: Array):
        """Applies the inverse flow to the latents."""
        return self.flow.inverse_and_log_det(inputs)

    def log_prob_base(self, x: Array):
        return self.base_dist.log_prob(x)

    def log_prob_transformed(self, x: Array):
        return self.trans_dist.log_prob(x)

# %%
def create_flow(config, init_shape):
    """Builds the normalizing flow model."""
    # Number of parameters for the rational-quadratic spline:
    # - `num_bins` bin widths
    # - `num_bins` bin heights
    # - `num_bins + 1` knot slopes
    # for a total of `3 * num_bins + 1` parameters.
    def bijector_fn(params):
        return distrax.RationalQuadraticSpline(
            params,
            range_min=config["spline_range_min"],
            range_max=config["spline_range_max"],
        )

    num_bijector_params = 3 * config["spline_bins"] + 1

    # Construct activation.
    activation = getattr(jax.nn, config["activation"], None)
    conditioners = []
    for _ in range(config["num_flow_layers"]):
        conditioner = FlowConditioner(
            event_shape=tuple((init_shape[-1],)),
            latent_sizes=config["latent_sizes"],
            activation=activation,
            num_bijector_params=num_bijector_params,
        )
        conditioners.append(conditioner)

    return NormalizingFlow(
        event_shape=init_shape[-1],
        bijector_fn=bijector_fn,
        conditioners=conditioners,
    )

# %% [markdown]
# # make target density

# %%
def dual_moon_logpdf(x, params=None):
    term1 = 0.5 * ((jnp.linalg.norm(x, axis=-1) - 2) / 0.4) ** 2
    term2 = -0.5 * ((x[..., :1] + jnp.array([-2.0, 2.0])) / 0.6) ** 2
    pe = term1 - special.logsumexp(term2, axis=-1)
    return -pe

# %%
@partial(jax.jit, static_argnums=(0, 1, 2, 4))
def mesh_eval(func, x_limits, y_limits, params=None, num_ticks=101):
    # Evaluate func on a 2D grid defined by x_limits and y_limits.
    x = np.linspace(*x_limits, num=num_ticks)
    y = np.linspace(*y_limits, num=num_ticks)
    X, Y = np.meshgrid(x, y)
    xy_vec = np.stack([X.ravel(), Y.ravel()]).T
    try:
        if params is not None:
            zs = jax.vmap(func, in_axes=(0, None))(xy_vec, params)
        else:
            zs = jax.vmap(func)(xy_vec)
    except:
        if params is not None:
            zs = func(xy_vec, params)
        else:
            zs = func(xy_vec)
    return X, Y, zs.reshape(X.shape)

# %%
x, y, z = mesh_eval(dual_moon_logpdf, (-3, 3), (-3, 3))
plt.contour(x, y, jnp.exp(z), cmap="summer")

# %% [markdown]
# # make flow

# %%
config = dict(
    spline_range_min=0.0,
    spline_range_max=1.0,
    spline_bins=50,
    activation="relu",
    num_flow_layers=8,
    latent_sizes=[500, 500],
)

# %%
flow = create_flow(
    config,
    (
        1,
        2,
    ),
)

# %%
key = random.PRNGKey(0)
params = flow.init(
    key,
    random.normal(
        key,
        (
            1,
            2,
        ),
    ),
)

# %%
flow_forward = jax.jit(partial(flow.apply, method=flow.forward))

# %%
def loss(params, key, n_samples=5):
    key, subkey = random.split(key)
    z = flow.apply(params, key, n_samples, method=flow.sample_base)
    x = flow_forward(params, z)
    l = dual_moon_logpdf(x) - flow.apply(params, x, method=flow.log_prob_base)
    return -l.mean()

# %%
def train_step(params, key, opt_state):
    l, grads = jax.value_and_grad(loss)(params, key)
    updates, opt_state = opt.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
    return params, opt_state, l


opt = optax.adam(1e-4)
opt_state = opt.init(params)

# %%
for i in (pbar := tqdm(range(100))):
    params, opt_state, l = train_step(params, key, opt_state)
    pbar.set_description(f"loss: {l:.2f}")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
z = flow.apply(params, key, 1000, method=flow.sample_base)
x = flow_forward(params, z)

# %%
plt.scatter(x[:, 0], x[:, 1])
plt.xlim(-5, 5)
plt.ylim(-5, 5)
# Out:
# (-5.0, 5.0)

# %%
xr = jnp.linspace(-3, 3)
yr = jnp.linspace(-3, 3)
xx, yy = jnp.meshgrid(xr, yr)
grid = jnp.stack((xx.ravel(), yy.ravel())).T
zz = flow.apply(params, grid, method=flow.log_prob_transformed)
zz = zz.reshape(xx.shape)

# %%
plt.contour(xx, yy, zz)

# %%
apply(flow.inverse_and_log_det, params, sample)
# Out:
# (DeviceArray([[-0.32842112,  0.3036082 ],
#               [-0.36644635, -0.8666133 ],
#               [-0.5196931 , -0.22369303],
#               [-1.6034249 , -1.2017536 ],
#               [ 0.7223841 ,  0.68187964]], dtype=float32),
#  DeviceArray([-0.76086086,  0.8591999 ,  0.5512196 ,  1.5805526 ,
#               -0.49520814], dtype=float32))

# %%
apply(flow.sample_and_log_prob_transformed, params, key, 5)
# Out:
# (DeviceArray([[-0.41054893,  0.20284171],
#               [-0.1004317 , -0.6766972 ],
#               [-0.39333144, -0.10865586],
#               [-0.4294003 , -0.39983326],
#               [ 0.73384684,  0.4333516 ]], dtype=float32),
#  DeviceArray([-2.0403004, -1.4434438, -1.4969294, -1.4003502, -2.900018 ],            dtype=float32))

# %%
jax.jit(partial(apply, flow.sample_and_log_prob_transformed))(params, key, 5)
# Out:
# ---------------------------------------------------------------------------
# ConcretizationTypeError                   Traceback (most recent call last)
# Cell In [283], line 1
# ----> 1 jax.jit(partial(apply, flow.sample_and_log_prob_transformed))(params, key, 5)
#
#     [... skipping hidden 11 frame]
#
# Cell In [273], line 1, in <lambda>(method, *args)
# ----> 1 apply = lambda method, *args: flow.apply(*args, method=method)
#
#     [... skipping hidden 6 frame]
#
# Cell In [241], line 58, in NormalizingFlow.sample_and_log_prob_transformed(self, key, n)
#      57 def sample_and_log_prob_transformed(self, key: PRNGKey, n: int):
# ---> 58     z = self.sample_transformed(key, n)
#      59     return z, self.log_prob_transformed(z)
#
#     [... skipping hidden 2 frame]
#
# Cell In [241], line 51, in NormalizingFlow.sample_transformed(self, key, n)
#      50 def sample_transformed(self, key: PRNGKey, n: int):
# ---> 51     z = self.sample_base(key, n)
#      52     return self.forward(z)
#
#     [... skipping hidden 2 frame]
#
# Cell In [241], line 48, in NormalizingFlow.sample_base(self, key, n)
#      47 def sample_base(self, key: PRNGKey, n: int):
# ---> 48     return self.base_dist.sample(seed=key, sample_shape=n)
#
# File /scratch/gpfs/js5013/.conda/envs/main/lib/python3.10/site-packages/distrax/_src/distributions/distribution.py:128, in Distribution.sample(self, seed, sample_shape)
#     115 def sample(self,
#     116            *,
#     117            seed: Union[IntLike, PRNGKey],
#     118            sample_shape: Union[IntLike, Sequence[IntLike]] = ()) -> Array:
#     119   """Samples an event.
#     120
#     121   Args:
#    (...)
#     126     A sample of shape `sample_shape` + `batch_shape` + `event_shape`.
#     127   """
# --> 128   rng, sample_shape = convert_seed_and_sample_shape(seed, sample_shape)
#     129   num_samples = functools.reduce(operator.mul, sample_shape, 1)  # product
#     131   samples = self._sample_n(rng, num_samples)
#
# File /scratch/gpfs/js5013/.conda/envs/main/lib/python3.10/site-packages/distrax/_src/distributions/distribution.py:249, in convert_seed_and_sample_shape(seed, sample_shape)
#     247 if not isinstance(sample_shape, collections.abc.Sequence):
#     248   sample_shape = (sample_shape,)
# --> 249 sample_shape = tuple(map(int, sample_shape))
#     251 if isinstance(seed, IntLike.__args__):
#     252   rng = jax.random.PRNGKey(seed)
#
#     [... skipping hidden 1 frame]
#
# File /scratch/gpfs/js5013/.conda/envs/main/lib/python3.10/site-packages/jax/core.py:1254, in concretization_function_error.<locals>.error(self, arg)
#    1253 def error(self, arg):
# -> 1254   raise ConcretizationTypeError(arg, fname_context)
#
# ConcretizationTypeError: Abstract tracer value encountered where concrete value is expected: Traced<ShapedArray(int32[], weak_type=True)>with<DynamicJaxprTrace(level=0/1)>
# The problem arose with the `int` function. If trying to convert the data type of a value, try using `x.astype(int)` or `jnp.array(x, int)` instead.
# The error occurred while tracing the function <lambda> at /tmp/ipykernel_3871109/4289663487.py:1 for jit. This concrete value was not available in Python because it depends on the value of the argument 'args'.
#
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.ConcretizationTypeError

# %%
jax.jit(applyflow.sample_and_log_prob_transformed, params, key, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [281], line 1
# ----> 1 jax.jit(apply)(flow.sample_and_log_prob_transformed, params, key, 5)
#
#     [... skipping hidden 2 frame]
#
# File /scratch/gpfs/js5013/.conda/envs/main/lib/python3.10/site-packages/jax/_src/api.py:3077, in _check_arg(arg)
#    3075 def _check_arg(arg):
#    3076   if not (isinstance(arg, core.Tracer) or _valid_jaxtype(arg)):
# -> 3077     raise TypeError(f"Argument '{arg}' of type {type(arg)} is not a valid JAX type.")
#
# TypeError: Argument '<bound method NormalizingFlow.sample_and_log_prob_transformed of JitNormalizingFlow()>' of type <class 'method'> is not a valid JAX type.
